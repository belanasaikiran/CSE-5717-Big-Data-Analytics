# %% [markdown]
# ## 92.5% of accuacy with 100 labels

# %% [markdown]
# ## Goal

# %% [markdown]
# In thie programming assignment, we use an example to show how we can use autoencoders and clustering to improve classification results.
#
# We use the mnist data set for this purpose. We are only allowed to lable 100 images from the training data set. But we are free to choose which 100 images to label.
#
# Given this limitation, we will combine autoencoders and clustering to reach a classification accuracy above 92.5%.

# %% [markdown]
# ## Grading Policy

# %% [markdown]
# This programming assignment is graded based on the achieved test accuracy. Any accuracy above 92.5% is graded as 100, whereas any accuracy below 97.5% is graded as 0. Any accuracy in between will be graded using the formula
#
# (test_acc - 0.915)*10000

# %% [markdown]
# ## Load the data

# %% [markdown]
# First, we load the mnist data and normalize the images. Note we use the last 5000 samples in the x_train_full for validation.

# %%
from tensorflow.keras.datasets import mnist
import numpy as np

(x_train_full, y_train_full), (x_test, y_test) = mnist.load_data()
x_train_full = x_train_full.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255
x_train, x_valid = x_train_full[:-5000], x_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

# %%
print(x_train.shape, x_valid.shape, x_test.shape)
# Out:
# (55000, 28, 28) (5000, 28, 28) (10000, 28, 28)

# %% [markdown]
# Next, we reshape the images to (28, 28, 1).

# %%
image_size = x_train.shape[1]
x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
x_valid = np.reshape(x_valid, [-1, image_size, image_size, 1])
x_test = np.reshape(x_test, [-1, image_size, image_size, 1])

# %% [markdown]
# We print out the first 100 training images.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 4))
for index, digit in enumerate(x_train[:100]):
    plt.subplot(100 // 10, 10, index + 1)
    plt.imshow(digit.reshape(28, 28), cmap="binary", interpolation="bilinear")
    plt.axis('off')

plt.show()

# %% [markdown]
# # Build  an autoencoder

# %% [markdown]
# First import some modules needed for this part of the code.

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten, Dropout
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# We build a autoencoder using Conv2D layers.
#
# First, we build the encoder. Hint: study the code from this module. Try different latent_dim settings.

# %%
# network parameters

# %%
# build the autoencoder model
# first build the encoder model

# %%
# shape info needed to build decoder model

shape = K.int_shape(x)

# %%
# generate latent vector

# %% [markdown]
# Now we build the decoder. Note in the decoder we use Conv2DTranspose layers.

# %%
# build the decoder model

# %%
# stack of Conv2DTranspose()-Conv2DTranspose()

# %%
# reconstruct the input

# %% [markdown]
# Combine the encoder and the decoder as the autocoder.

# %% [markdown]
# Compile the autoencoder.

# %%
# Mean Square Error (MSE) loss function, Adam optimizer
autoencoder.compile(loss='mse', optimizer='adam')

# %% [markdown]
# Train the autoencoder. Use restore_best_weights to restore the best weights.

# %%
# train the autoencoder
history = autoencoder.fit(x_train,
                x_train,
                validation_data=(x_valid, x_valid),
                epochs=100,
                batch_size=batch_size, callbacks=[EarlyStopping(patience=20, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 15s 5ms/step - loss: 0.0257 - val_loss: 0.0358
# Epoch 2/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0134 - val_loss: 0.0344
# Epoch 3/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0121 - val_loss: 0.0354
# Epoch 4/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0114 - val_loss: 0.0360
# Epoch 5/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0109 - val_loss: 0.0360
# Epoch 6/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0106 - val_loss: 0.0344
# Epoch 7/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0103 - val_loss: 0.0296
# Epoch 8/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0101 - val_loss: 0.0315
# Epoch 9/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0099 - val_loss: 0.0306
# Epoch 10/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0098 - val_loss: 0.0305
# Epoch 11/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0096 - val_loss: 0.0318
# Epoch 12/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0095 - val_loss: 0.0295
# Epoch 13/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0094 - val_loss: 0.0270
# Epoch 14/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0094 - val_loss: 0.0298
# Epoch 15/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0093 - val_loss: 0.0291
# Epoch 16/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0092 - val_loss: 0.0308
# Epoch 17/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0092 - val_loss: 0.0274
# Epoch 18/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0091 - val_loss: 0.0289
# Epoch 19/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0091 - val_loss: 0.0283
# Epoch 20/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0090 - val_loss: 0.0278
# Epoch 21/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0089 - val_loss: 0.0258
# Epoch 22/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0089 - val_loss: 0.0285
# Epoch 23/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0089 - val_loss: 0.0266
# Epoch 24/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0088 - val_loss: 0.0284
# Epoch 25/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0088 - val_loss: 0.0278
# Epoch 26/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0088 - val_loss: 0.0290
# Epoch 27/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0087 - val_loss: 0.0286
# Epoch 28/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0087 - val_loss: 0.0249
# Epoch 29/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0087 - val_loss: 0.0260
# Epoch 30/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0087 - val_loss: 0.0262
# Epoch 31/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 32/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0086 - val_loss: 0.0281
# Epoch 33/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0086 - val_loss: 0.0256
# Epoch 34/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0086 - val_loss: 0.0252
# Epoch 35/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0086 - val_loss: 0.0269
# Epoch 36/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0085 - val_loss: 0.0264
# Epoch 37/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0085 - val_loss: 0.0259
# Epoch 38/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0085 - val_loss: 0.0246
# Epoch 39/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0085 - val_loss: 0.0259
# Epoch 40/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0085 - val_loss: 0.0253
# Epoch 41/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0085 - val_loss: 0.0268
# Epoch 42/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0085 - val_loss: 0.0273
# Epoch 43/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0256
# Epoch 44/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0084 - val_loss: 0.0255
# Epoch 45/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0262
# Epoch 46/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0266
# Epoch 47/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0230
# Epoch 48/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0250
# Epoch 49/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0266
# Epoch 50/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0084 - val_loss: 0.0256
# Epoch 51/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0254
# Epoch 52/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0259
# Epoch 53/100
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.0083 - val_loss: 0.0259
# Epoch 54/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0254
# Epoch 55/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0263
# Epoch 56/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0259
# Epoch 57/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0259
# Epoch 58/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0246
# Epoch 59/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0083 - val_loss: 0.0270
# Epoch 60/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0083 - val_loss: 0.0240
# Epoch 61/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0083 - val_loss: 0.0239
# Epoch 62/100
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.0082 - val_loss: 0.0273
# Epoch 63/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0082 - val_loss: 0.0272
# Epoch 64/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0082 - val_loss: 0.0250
# Epoch 65/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0082 - val_loss: 0.0257
# Epoch 66/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0082 - val_loss: 0.0244
# Epoch 67/100
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.0082 - val_loss: 0.0242

# %% [markdown]
# Plot training and validation losses during the traing.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# Obtain the encoded training set and validation set.

# %%
x_train_encoded = encoder.predict(x_train)
x_valid_encoded = encoder.predict(x_valid)

print(x_train_encoded.shape, x_valid_encoded.shape)
# Out:
# 1719/1719 [==============================] - 2s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# (55000, 16) (5000, 16)

# %% [markdown]
# ## Cluster encoded training data to select 100 images for labeling

# %% [markdown]
# First, we use k-means to find 100 centroids of the encoded training images and label these images.

# %%
from sklearn.cluster import KMeans
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Display these 100 images.

# %%
plt.figure(figsize=(16, 4))
for index, x_representative_digit in enumerate(x_representative_digits):
    plt.subplot(k // 10, 10, index + 1)
    plt.imshow(x_representative_digit.reshape(28, 28), cmap="binary", interpolation="bilinear")
    plt.axis('off')

plt.show()

# %% [markdown]
# Print the labels to confirm they are correct.

# %%
y_representative_digits = np.empty([k])
for i, idx in enumerate(representative_digit_idx):
  y_representative_digits[i] = y_train[idx]
print(y_representative_digits)
# Out:
# [8. 1. 5. 9. 0. 7. 9. 0. 2. 5. 5. 2. 4. 9. 7. 1. 5. 6. 1. 9. 2. 7. 2. 6.
#  8. 4. 0. 6. 3. 8. 6. 8. 6. 9. 4. 0. 0. 3. 3. 0. 2. 3. 8. 6. 5. 5. 7. 2.
#  3. 4. 5. 8. 4. 9. 6. 2. 7. 0. 2. 1. 2. 5. 2. 6. 6. 2. 4. 3. 4. 4. 9. 5.
#  3. 7. 3. 9. 3. 1. 7. 0. 6. 4. 2. 9. 9. 1. 4. 3. 7. 0. 5. 2. 4. 7. 7. 8.
#  2. 0. 7. 1.]

# %%
print(x_representative_digits.shape)
print(y_representative_digits.shape)
# Out:
# (100, 28, 28, 1)
# (100,)

# %% [markdown]
# ## Propagate labels and train model for classification

# %% [markdown]
# Propagate labels to images that are close to the 100 centroids in the latent space. Hint: study the code provied from the clustering module and try different percentile_closest values.

# %%
y_train_propagated = np.empty(len(x_train), dtype=np.int32)
for i in range(k):
    y_train_propagated[kmeans.labels_==i] = y_representative_digits[i]

# %%
percentile_closest =

x_cluster_dist = x_digits_dist[np.arange(len(x_train_encoded)), kmeans.labels_]
for i in range(k):
    in_cluster = (kmeans.labels_ == i)
    cluster_dist = x_cluster_dist[in_cluster]
    cutoff_distance = np.percentile(cluster_dist, percentile_closest)
    above_cutoff = (x_cluster_dist > cutoff_distance)
    x_cluster_dist[in_cluster & above_cutoff] = -1

# %% [markdown]
# Prepare data for classification. Use images with propogated labels and save 5,000 images for validation.

# %%
partially_propagated = (x_cluster_dist != -1)
x_train_partially_propagated = x_train[partially_propagated]
y_train_partially_propagated = y_train_propagated[partially_propagated]

# %%
print(x_train_partially_propagated.shape)
print(y_train_partially_propagated.shape)

# %%
x_rep_train = x_train_partially_propagated[:-5000]
y_rep_train = y_train_partially_propagated[:-5000]
x_rep_valid = x_train_partially_propagated[-5000:]
y_rep_valid = y_train_partially_propagated[-5000:]

# %%
print(x_rep_train.shape, x_rep_valid.shape)

# %%
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(y_rep_train)
valid_labels = to_categorical(y_rep_valid)
test_labels = to_categorical(y_test)

# %% [markdown]
# Define the image classification model.

# %%
from keras import layers
from keras import models

def build_model():

    # we build a Y-network model with two inputs and one output

    # fill in code

    # outputs
    outputs = layers.Dense(10, activation='softmax')(x)
    model = models.Model([left_inputs, right_inputs], outputs=outputs)
    return model
model = build_model()
model.summary()

# %%
model.compile(optimizer='nadam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit([x_rep_train, x_rep_train], train_labels, validation_data=([x_rep_valid, x_rep_valid], valid_labels), epochs=100, batch_size=32,
                    callbacks=[EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 704/704 [==============================] - 22s 16ms/step - loss: 0.3156 - accuracy: 0.9073 - val_loss: 0.1019 - val_accuracy: 0.9628
# Epoch 2/100
# 704/704 [==============================] - 10s 15ms/step - loss: 0.1478 - accuracy: 0.9538 - val_loss: 0.0983 - val_accuracy: 0.9672
# Epoch 3/100
# 704/704 [==============================] - 10s 15ms/step - loss: 0.1256 - accuracy: 0.9591 - val_loss: 0.0885 - val_accuracy: 0.9692
# Epoch 4/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.1097 - accuracy: 0.9645 - val_loss: 0.0766 - val_accuracy: 0.9734
# Epoch 5/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0961 - accuracy: 0.9680 - val_loss: 0.0785 - val_accuracy: 0.9718
# Epoch 6/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0894 - accuracy: 0.9703 - val_loss: 0.0694 - val_accuracy: 0.9750
# Epoch 7/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0860 - accuracy: 0.9722 - val_loss: 0.0864 - val_accuracy: 0.9712
# Epoch 8/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0833 - accuracy: 0.9729 - val_loss: 0.0689 - val_accuracy: 0.9768
# Epoch 9/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0790 - accuracy: 0.9738 - val_loss: 0.0699 - val_accuracy: 0.9760
# Epoch 10/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0670 - accuracy: 0.9768 - val_loss: 0.0865 - val_accuracy: 0.9706
# Epoch 11/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0656 - accuracy: 0.9789 - val_loss: 0.0650 - val_accuracy: 0.9770
# Epoch 12/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0684 - accuracy: 0.9774 - val_loss: 0.0862 - val_accuracy: 0.9714
# Epoch 13/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0547 - accuracy: 0.9813 - val_loss: 0.0709 - val_accuracy: 0.9762
# Epoch 14/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0549 - accuracy: 0.9818 - val_loss: 0.0704 - val_accuracy: 0.9750
# Epoch 15/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0454 - accuracy: 0.9843 - val_loss: 0.0660 - val_accuracy: 0.9758
# Epoch 16/100
# 704/704 [==============================] - 12s 17ms/step - loss: 0.0491 - accuracy: 0.9831 - val_loss: 0.0741 - val_accuracy: 0.9772
# Epoch 17/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0468 - accuracy: 0.9842 - val_loss: 0.0703 - val_accuracy: 0.9762
# Epoch 18/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0468 - accuracy: 0.9837 - val_loss: 0.0585 - val_accuracy: 0.9798
# Epoch 19/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0404 - accuracy: 0.9865 - val_loss: 0.0616 - val_accuracy: 0.9790
# Epoch 20/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0391 - accuracy: 0.9869 - val_loss: 0.0682 - val_accuracy: 0.9786
# Epoch 21/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0305 - accuracy: 0.9900 - val_loss: 0.0769 - val_accuracy: 0.9792
# Epoch 22/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.0768 - val_accuracy: 0.9776
# Epoch 23/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.0758 - val_accuracy: 0.9764
# Epoch 24/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0321 - accuracy: 0.9891 - val_loss: 0.0788 - val_accuracy: 0.9784
# Epoch 25/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0275 - accuracy: 0.9909 - val_loss: 0.0669 - val_accuracy: 0.9796
# Epoch 26/100
# 704/704 [==============================] - 11s 16ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.0814 - val_accuracy: 0.9774
# Epoch 27/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0299 - accuracy: 0.9905 - val_loss: 0.0786 - val_accuracy: 0.9762
# Epoch 28/100
# 704/704 [==============================] - 11s 15ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0734 - val_accuracy: 0.9784

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()   # clear figure
acc_values = history.history['accuracy']
val_acc_values = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Final step: test accuracy and grading

# %% [markdown]
# Note, we should only run this step once. We should look at the validation accuracy results before this step. If we are happy with the results, we run this step. Otherwise, we adjust settings in the previous steps until we get satisfying validation accuracy results.

# %%
test_loss, test_acc = model.evaluate([x_test, x_test], test_labels)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3249 - accuracy: 0.9284

# %%
grade = max(min((test_acc - 0.915)*10000,100), 0)
print('My grade: ', grade)
# Out:
# My grade:  100
