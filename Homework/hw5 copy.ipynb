# %% [markdown]
# Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# In this assginment, we try to build a classifier for the Fashion-MNIST dataset that achieves over 94% accuracy on the test set.
#
# To achieve this goal, we
# - use convnet for this purpose
# - learn how to use padding in convnet
# - learn how to use Batch Normalization and Dropout when training deep neural networks
# - learn how to use nadam optimizer
# - add more layers to the exisiting network model in function build_model()
# - use validation data and observe the training history to determine whether the model is good enough to run test data
# - use test data set only once.
#
# This assignment is graded on the test accuracy. Any accuracy below 93% is graded as 0; any accuracy above 94% is graded as 100. Any grade in between is graded using the fomula  (acc - 0.93)/(0.94 - 0.93), 1))*100.

# %%
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ### Labels
# Each training and test example is assigned to one of the following labels:
#
# Label	Description
# - 0	T-shirt/top
# - 1	Trouser
# - 2	Pullover
# - 3	Dress
# - 4	Coat
# - 5	Sandal
# - 6	Shirt
# - 7	Sneaker
# - 8	Bag
# - 9	Ankle boot

# %%
def plot_digit(data):
    image = data.reshape(28, 28)
    plt.imshow(image, cmap = matplotlib.cm.binary, interpolation="nearest")
    plt.axis("off")

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

some_digit = X_train[36001]
some_digit_image = some_digit.reshape(28, 28)
plt.imshow(some_digit_image, cmap = matplotlib.cm.binary, interpolation="nearest")
plt.axis("off");

# %%
plot_digit(X_train[40000])

# %%
def plot_digits(instances, images_per_row=10, **options):
    size = 28
    images_per_row = min(len(instances), images_per_row)
    images = [instance.reshape(size,size) for instance in instances]
    n_rows = (len(instances) - 1) // images_per_row + 1
    row_images = []
    n_empty = n_rows * images_per_row - len(instances)
    images.append(np.zeros((size, size * n_empty)))
    for row in range(n_rows):
        rimages = images[row * images_per_row : (row + 1) * images_per_row]
        row_images.append(np.concatenate(rimages, axis=1))
    image = np.concatenate(row_images, axis=0)
    plt.imshow(image, cmap = matplotlib.cm.binary, **options)
    plt.axis("off")

# %%
plt.figure(figsize=(9,9))
X_0 = X_train[(y_train == 0)]
example_images = X_0[:100]
plot_digits(example_images, images_per_row=10)

# %%
plt.figure(figsize=(9,9))
X_1 = X_train[(y_train == 1)]
example_images = X_1[:100]
plot_digits(example_images, images_per_row=10)

# %%
plt.figure(figsize=(9,9))
X_2 = X_train[(y_train == 2)]
example_images = X_2[:100]
plot_digits(example_images, images_per_row=10)

# %%
from keras import layers
from keras import models

def build_model():

    # we build a Y-network model with two inputs and one output

    input_shape=(28, 28, 1)
    
    # left branch
    left_inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, (3, 3), padding="same", activation='relu')(left_inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(32, (3, 3), padding="same", activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.25)(x)

    # fill in code below to finsh the left branch



    # right branch
    right_inputs = layers.Input(shape=input_shape)
    y = layers.Conv2D(32, (3, 3), padding="same", activation='relu')(right_inputs)
    y = layers.BatchNormalization()(y)
    y = layers.Conv2D(32, (3, 3), padding="same", activation='relu')(y)
    y = layers.BatchNormalization()(y)
    y = layers.MaxPooling2D((2, 2))(y)
    y = layers.Dropout(0.25)(y)

    # fill in code below to finish the right branch



    # concatenate the left and the right branches
    x = layers.concatenate([x, y])
    x = layers.Flatten()(x)

    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # fill in code below


    # outputs
    outputs = layers.Dense(10, activation='softmax')(x)
    model = models.Model([left_inputs, right_inputs], outputs=outputs)
    return model
model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 32)   9248        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 14, 14, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 14, 14, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 14, 14, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 64)   0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 12544)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          6423040     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        batch_normalization_4[0][0]
# ==================================================================================================
# Total params: 6,449,866
# Trainable params: 6,448,586
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import to_categorical

X_train = X_train.reshape((60000, 28, 28, 1))
X_train = X_train.astype('float32') / 255
y_train = to_categorical(y_train)

X_test = X_test.reshape((10000, 28, 28, 1))
X_test = X_test.astype('float32') / 255
y_test = to_categorical(y_test)

X_val = X_train[:10000]
y_val = y_train[:10000]

X_train_partial = X_train[10000:]
y_train_partial = y_train[10000:]

# %%
X_train_partial.shape, y_train_partial.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 28, 28, 1), (50000, 10), (10000, 28, 28, 1), (10000, 10))

# %%
model.compile(optimizer='nadam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit([X_train_partial, X_train_partial], y_train_partial, epochs=40, batch_size=32, validation_data=([X_val, X_val], y_val))
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - 32s 9ms/step - loss: 0.4799 - accuracy: 0.8386 - val_loss: 0.2949 - val_accuracy: 0.8979
# Epoch 2/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2546 - accuracy: 0.9088 - val_loss: 1.0736 - val_accuracy: 0.8070
# Epoch 3/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2172 - accuracy: 0.9203 - val_loss: 0.2801 - val_accuracy: 0.8994
# Epoch 4/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.1694 - accuracy: 0.9390 - val_loss: 0.2582 - val_accuracy: 0.9084
# Epoch 5/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.1485 - accuracy: 0.9457 - val_loss: 0.4481 - val_accuracy: 0.8901
# Epoch 6/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.1226 - accuracy: 0.9548 - val_loss: 0.2246 - val_accuracy: 0.9259
# Epoch 7/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.1135 - accuracy: 0.9572 - val_loss: 0.2234 - val_accuracy: 0.9276
# Epoch 8/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0816 - accuracy: 0.9707 - val_loss: 0.3092 - val_accuracy: 0.9147
# Epoch 9/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0728 - accuracy: 0.9734 - val_loss: 0.2386 - val_accuracy: 0.9309
# Epoch 10/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0534 - accuracy: 0.9798 - val_loss: 0.2747 - val_accuracy: 0.9281
# Epoch 11/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0523 - accuracy: 0.9814 - val_loss: 0.2514 - val_accuracy: 0.9295
# Epoch 12/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0539 - accuracy: 0.9803 - val_loss: 0.2781 - val_accuracy: 0.9264
# Epoch 13/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0310 - accuracy: 0.9883 - val_loss: 0.2957 - val_accuracy: 0.9290
# Epoch 14/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0426 - accuracy: 0.9842 - val_loss: 0.2900 - val_accuracy: 0.9322
# Epoch 15/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.3075 - val_accuracy: 0.9328
# Epoch 16/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0275 - accuracy: 0.9897 - val_loss: 0.3563 - val_accuracy: 0.9298
# Epoch 17/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0297 - accuracy: 0.9897 - val_loss: 0.3600 - val_accuracy: 0.9094
# Epoch 18/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.3190 - val_accuracy: 0.9320
# Epoch 19/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0203 - accuracy: 0.9929 - val_loss: 0.3314 - val_accuracy: 0.9271
# Epoch 20/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0235 - accuracy: 0.9922 - val_loss: 0.3899 - val_accuracy: 0.9252
# Epoch 21/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0230 - accuracy: 0.9919 - val_loss: 0.3929 - val_accuracy: 0.9282
# Epoch 22/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.3680 - val_accuracy: 0.9327
# Epoch 23/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 0.4068 - val_accuracy: 0.9272
# Epoch 24/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0255 - accuracy: 0.9911 - val_loss: 0.4031 - val_accuracy: 0.9305
# Epoch 25/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.4243 - val_accuracy: 0.9246
# Epoch 26/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.4035 - val_accuracy: 0.9319
# Epoch 27/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.4138 - val_accuracy: 0.9270
# Epoch 28/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.3964 - val_accuracy: 0.9289
# Epoch 29/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0137 - accuracy: 0.9949 - val_loss: 0.4053 - val_accuracy: 0.9314
# Epoch 30/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0157 - accuracy: 0.9941 - val_loss: 0.4034 - val_accuracy: 0.9324
# Epoch 31/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.4065 - val_accuracy: 0.9316
# Epoch 32/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.4303 - val_accuracy: 0.9275
# Epoch 33/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.4471 - val_accuracy: 0.9304
# Epoch 34/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.4657 - val_accuracy: 0.9321
# Epoch 35/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.4291 - val_accuracy: 0.9331
# Epoch 36/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.4566 - val_accuracy: 0.9328
# Epoch 37/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.4587 - val_accuracy: 0.9311
# Epoch 38/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.4404 - val_accuracy: 0.9305
# Epoch 39/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.4314 - val_accuracy: 0.9307
# Epoch 40/40
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.4672 - val_accuracy: 0.9211

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()   # clear figure
acc_values = history.history['accuracy']
val_acc_values = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model = build_model()
model.compile(optimizer='nadam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit([X_train, X_train], y_train, epochs=40, batch_size=32)
# Out:
# Epoch 1/40
# 1875/1875 [==============================] - 16s 7ms/step - loss: 0.4718 - accuracy: 0.8432
# Epoch 2/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2418 - accuracy: 0.9110
# Epoch 3/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1898 - accuracy: 0.9311
# Epoch 4/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1607 - accuracy: 0.9407
# Epoch 5/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1296 - accuracy: 0.9525
# Epoch 6/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1162 - accuracy: 0.9575
# Epoch 7/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0848 - accuracy: 0.9693
# Epoch 8/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0693 - accuracy: 0.9759
# Epoch 9/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0554 - accuracy: 0.9801
# Epoch 10/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0442 - accuracy: 0.9837
# Epoch 11/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0473 - accuracy: 0.9835
# Epoch 12/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0369 - accuracy: 0.9864
# Epoch 13/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0329 - accuracy: 0.9885
# Epoch 14/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0312 - accuracy: 0.9884
# Epoch 15/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0351 - accuracy: 0.9872
# Epoch 16/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0238 - accuracy: 0.9916
# Epoch 17/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0208 - accuracy: 0.9926
# Epoch 18/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0244 - accuracy: 0.9914
# Epoch 19/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0269 - accuracy: 0.9905
# Epoch 20/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0167 - accuracy: 0.9945
# Epoch 21/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0214 - accuracy: 0.9923
# Epoch 22/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0192 - accuracy: 0.9933
# Epoch 23/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0166 - accuracy: 0.9943
# Epoch 24/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0177 - accuracy: 0.9939
# Epoch 25/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0161 - accuracy: 0.9946
# Epoch 26/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0184 - accuracy: 0.9938
# Epoch 27/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0130 - accuracy: 0.9959
# Epoch 28/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0128 - accuracy: 0.9957
# Epoch 29/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0153 - accuracy: 0.9946
# Epoch 30/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0145 - accuracy: 0.9949
# Epoch 31/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0100 - accuracy: 0.9969
# Epoch 32/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0119 - accuracy: 0.9958
# Epoch 33/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0186 - accuracy: 0.9935
# Epoch 34/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0132 - accuracy: 0.9952
# Epoch 35/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0091 - accuracy: 0.9967
# Epoch 36/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0135 - accuracy: 0.9955
# Epoch 37/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0109 - accuracy: 0.9968
# Epoch 38/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0130 - accuracy: 0.9956
# Epoch 39/40
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0098 - accuracy: 0.9971
# Epoch 40/40
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0111 - accuracy: 0.9962

# %%
acc = model.evaluate([X_test, X_test], y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4710 - accuracy: 0.9309

# %%
grade = max(0, min((acc[1] - 0.93)/(0.94 - 0.93), 1))*100
print('My grade:', grade)
# Out:
# My grade: 8.999776840209565
